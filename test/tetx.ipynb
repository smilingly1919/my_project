# %%
import sys, os
sys.path.append(os.path.abspath('..'))  # 相对于当前 Notebook 的目录
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))) #对于py文件
from sdf_utils import *
# python -m sdf_utils 作为包导入
# print(a(123))

# %%
import sdf_helper as sh
import numpy as np
import matplotlib.pyplot as plt
import os

# === 文件路径设置 ===
base_dir = '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch/epoch3d/Cpf-Work/cone/cone1-a=145-1微米'
file_name = 'distfun0180.sdf'
file_path = os.path.join(base_dir, file_name)

# %%
load_distfun(file_path,"Photon","px_py")

result = load_distfun(file_path, "Electron", "px_py")

print("所有键：", result.keys())
# Out:
# 所有键： dict_keys(['dist', 'grid_x', 'grid_y'])

# %%
import os
import sdf_helper as sh  # 假设你已经导入了

# 基础路径列表（可按需求增减）
base_paths = [
    '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch/epoch3d/Cpf-Work/cone/cone1-a=145-0.5微米',
    '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch/epoch3d/Cpf-Work/cone/cone1-a=145-1微米',
    '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch/epoch3d/Cpf-Work/cone/cone1-a=145-1.5微米',
    '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch/epoch3d/Cpf-Work/cone/cone1-a=145-2微米',
]

file_index = 90
file_name = f"distfun{file_index:04d}.sdf"

# 用列表推导批量拼路径
file_paths = [os.path.join(bp, file_name) for bp in base_paths]

# 批量加载数据，存进列表
data_list = [sh.getdata(fp) for fp in file_paths]
# Out:
# Reading file /media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch/epoch3d/Cpf-Work/cone/cone1-a=145-0.5微米/distfun0090.sdf
# t() = time
# x(2501, 351, 351) = grid
# y(2501, 351, 351) = grid
# z(2501, 351, 351) = grid
# xc(2500, 350, 350) = grid_mid
# yc(2500, 350, 350) = grid_mid
# zc(2500, 350, 350) = grid_mid
# Reading file /media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch/epoch3d/Cpf-Work/cone/cone1-a=145-1微米/distfun0090.sdf
# t() = time
# x(2501, 351, 351) = grid
# y(2501, 351, 351) = grid
# z(2501, 351, 351) = grid
# xc(2500, 350, 350) = grid_mid
# yc(2500, 350, 350) = grid_mid
# zc(2500, 350, 350) = grid_mid
# Reading file /media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch/epoch3d/Cpf-Work/cone/cone1-a=145-1.5微米/distfun0090.sdf
# t() = time
# x(2501, 351, 351) = grid
# y(2501, 351, 351) = grid
# z(2501, 351, 351) = grid
# xc(2500, 350, 350) = grid_mid
# yc(2500, 350, 350) = grid_mid
# zc(2500, 350, 350) = grid_mid
# ...

# %%
result = load_distfun(file_paths[0], "Electron", "py_pz")
result1 = load_distfun(file_paths[1], "Electron", "py_pz")
result2 = load_distfun(file_paths[2], "Electron", "py_pz")
result3 = load_distfun(file_paths[3], "Electron", "py_pz")

print("所有键：", result.keys())

dist,dist1,dist2,dist3 = result['dist'],result1['dist'],result2['dist'],result3['dist']
grid_x0, grid_y0 = result['grid_x'], result['grid_y']
grid_x1, grid_y1 = result1['grid_x'], result1['grid_y']
grid_x2, grid_y2 = result2['grid_x'], result2['grid_y']
grid_x3, grid_y3 = result3['grid_x'], result3['grid_y']

# # grid_x, grid_y 有可能是二维坐标矩阵（meshgrid形式）
# # dist 是对应的二维分布函数数据

# plt.figure(figsize=(8,6))
# plt.pcolormesh(grid_x0, grid_y0, dist, shading='auto', cmap='viridis', vmax=1e8)
# plt.pcolormesh(grid_x1, grid_y1, dist1, shading='auto', cmap='viridis', vmax=1e8)
# plt.pcolormesh(grid_x2, grid_y2, dist2, shading='auto', cmap='viridis', vmax=1e8)
# plt.pcolormesh(grid_x3, grid_y3, dist3, shading='auto', cmap='viridis', vmax=1e8)
# plt.colorbar(label='Distribution function value')

# plt.xlabel('Grid X')
# plt.ylabel('Grid Y')
# plt.title('2D Distribution Function')
# plt.xlim(-1e-20,1e-20)
# plt.ylim(-1e-20,1e-20)
# plt.tight_layout()
# plt.show()
# Out:
# 所有键： dict_keys(['dist', 'grid_x', 'grid_y'])
